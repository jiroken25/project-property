# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
merged_data = 'parkeraff.csv'
pd.set_option('display.max_columns', None)
aff_df = pd.read_csv(merged_data)
aff_df.head()
# Out:
#    Unnamed: 0                        SA2 Name  Unoccupied Rate  Median Income  Median Rent  Median Mortgage  Purchasing Affordability Index  Rental Affordability Index  Building Approval  Unemplotment Rate
# 0        67.0   Alexander Heights - Koondoola         0.053029    1589.375000   354.417293       404.625029                      117.840585                  134.534208                204           0.104970
# 1        77.0              Alkimos - Eglinton         0.126659    2130.120482   365.544872       523.791781                      122.001942                  174.817428                568           0.062388
# 2       130.0            Applecross - Ardross         0.119067    2755.291005   489.366516       691.023025                      119.617910                  168.909657                 89           0.062757
# ...

# %%
#Building Approval vs. RAI



plt.scatter(aff_df['Building Approval'],aff_df['Rental Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Building Approval vs. RAI")
plt.xlabel('Building Approval')
plt.ylabel('Rental Affordability')

plt.savefig("building_vs.RAI.png")
plt.show()

# %%
#Unoccupied vs. RAI



plt.scatter(aff_df['Unoccupied Rate'],aff_df['Rental Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Unoccupied Rate vs. RAI")
plt.xlabel('Unoccupied Rate')
plt.ylabel('Rental Affordability')

plt.savefig("Unoccupied Rate_vs.RAI.png")
plt.show()

# %%
#Unemployment vs. RAI



plt.scatter(aff_df['Unemplotment Rate'],aff_df['Rental Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Unemplotment Rate vs. RAI")
plt.xlabel('Unemplotment Rate')
plt.ylabel('Rental Affordability')

plt.savefig("Unemplotment Rate_vs.RAI.png")
plt.show()

# %%
#Building Approval vs. PAI



plt.scatter(aff_df['Building Approval'],aff_df['Purchasing Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Building Approval vs. PAI")
plt.xlabel('Building Approval')
plt.ylabel('PAI')

plt.savefig("building_vs.PAI.png")
plt.show()

# %%
#Unoccupied vs. PAI



plt.scatter(aff_df['Unoccupied Rate'],aff_df['Purchasing Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Unoccupied Rate vs. PAI")
plt.xlabel('Unoccupied Rate')
plt.ylabel('PAI')

plt.savefig("Unoccupied Rate_vs.PAI.png")
plt.show()

# %%
#Unemployment vs. PAI



plt.scatter(aff_df['Unemplotment Rate'],aff_df['Purchasing Affordability Index'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()

plt.title(f"Unemplotment Rate vs. PAI")
plt.xlabel('Unemplotment Rate')
plt.ylabel(' PAI')

plt.savefig("Unemplotment Rate_vs.PAI.png")
plt.show()

# %%
#Linear Regression

def create_linear_regression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    print(f"The r-squared is: {rvalue}")

    plt.show()

# %%
aff_df.head()
# Out:
#    Unnamed: 0                        SA2 Name  Unoccupied Rate  Median Income  Median Rent  Median Mortgage  Purchasing Affordability Index  Rental Affordability Index  Building Approval  Unemplotment Rate
# 0        67.0   Alexander Heights - Koondoola         0.053029    1589.375000   354.417293       404.625029                      117.840585                  134.534208                204           0.104970
# 1        77.0              Alkimos - Eglinton         0.126659    2130.120482   365.544872       523.791781                      122.001942                  174.817428                568           0.062388
# 2       130.0            Applecross - Ardross         0.119067    2755.291005   489.366516       691.023025                      119.617910                  168.909657                 89           0.062757
# ...

# %%
xlbl = "Building Approval"
ylbl = "Rental Affordability Index"
lblpos = (50,25)

create_linear_regression(aff_df[xlbl],aff_df[ylbl],xlbl,ylbl,lblpos,5)

plt.savefig("linBR.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f7fd6a05f740> in <module>
#       3 lblpos = (50,25)
#       4
# ----> 5 create_linear_regression(aff_df[xlbl],aff_df[ylbl],xlbl,ylbl,lblpos,5)
#       6
#       7 plt.savefig("linBR.png")
#
# <ipython-input-9-16e76383804f> in create_linear_regression(xdata, ydata, xlbl, ylbl, lblpos, ifig)
#       2
#       3 def create_linear_regression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
# ----> 4     (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
#       5     regress_values = xdata * slope + intercept
#       6     line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'linregress' is not defined
